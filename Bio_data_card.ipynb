# %% [markdown]
# <a href="https://colab.research.google.com/github/Rupeshycho/1month-ai-course/blob/main/Bio_data_card.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#personal Bio data card
#a program that collects a person's details and stores each piece in the #appropriate Python data type, then prints a formatted bio-data card

f_name=input("Full Name: ")
city=input("Enter your city: ")
height=float(input(f'Enter your height: '))

print(f'Height:{height:.2f}')

answer = input("Enter your answer(yes/no): ")
if answer.lower().strip()== "yes":
  is_student= True
else:
  is_student= False
print(is_student)


birth_day=int(input("Enter you birth day: "))
birth_month =int(input("Enter your birth month: "))
birth_year=int(input("Enter your birth year: "))

dob=(birth_day, birth_month, birth_year)

hobbies =[]
for i in range(3):
  hobby=input(f"Enter your hobbies{i+1}:")
  hobbies.append(hobby)
print(hobbies)

language=set()
for i in range(3):
  lang=input(f"Enter the language{i+1}: ")
  language.add(lang)
print("The Three Languages: ", language)

profile ={
    "Full Name: ": f_name,
    "Location: ": city,
    "Student: ": is_student,
    "Date Of Birth: ": dob,
    "Hobbies: ": hobbies,
    "Languages: ": language
}


print("First Letter: ", first_letter)
print("Total Hobbies: ", len(hobbies))
print("Total no. of language he can speak: ", len(language))


print("Student Profile".center(40,"-"))
for key, value in profile.items():
  print(f'{key}{type(value)}: {value}')
# Out:
# Full Name: r
# Enter your city: r
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6374/3270753317.py in <cell line: 0>()
#       4 f_name=input("Full Name: ")
#       5 city=input("Enter your city: ")
# ----> 6 height=float(f'Enter your height: .2f')
#       7 answer = input("Enter your answer(yes/no): ")
#       8 if answer.lower().strip()== "yes":
#
# ValueError: could not convert string to float: 'Enter your height: .2f'
